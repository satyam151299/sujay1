# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=(12.0,9.0)

# %%
data=pd.read_csv("1.01. Simple linear regression.csv")

# %%
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
x
# Out:
# array([1714, 1664, 1760, 1685, 1693, 1670, 1764, 1764, 1792, 1850, 1735,
#        1775, 1735, 1712, 1773, 1872, 1755, 1674, 1842, 1786, 1761, 1722,
#        1663, 1687, 1974, 1826, 1787, 1821, 2020, 1794, 1769, 1934, 1775,
#        1855, 1880, 1849, 1808, 1954, 1777, 1831, 1865, 1850, 1966, 1702,
#        1990, 1925, 1824, 1956, 1857, 1979, 1802, 1855, 1907, 1634, 1879,
#        1887, 1730, 1953, 1781, 1891, 1964, 1808, 1893, 2041, 1893, 1832,
#        1850, 1934, 1861, 1931, 1933, 1778, 1975, 1934, 2021, 2015, 1997,
#        2020, 1843, 1936, 1810, 1987, 1962, 2050], dtype=int64)

# %%
x=data.iloc[:,0].values
y=data.iloc[:,1].values

# %%
def gradient(x,y):
    m=0
    c=0
    ittration=1000
    learning_rate=0.0000001
    n=len(x)
    for i in range(ittration):
        print(x)
        y_pred=m*x+c
        cost=(1/n)*sum([j**2 for j in (y-y_pred)])
        m_curr=(-2/n)*sum(x*(y-y_pred))
        c_curr=(-2/n)*sum(y-y_pred)
        m=m-(learning_rate*m_curr)
        c=c-(learning_rate*c_curr)
        print(cost)
    return m,c

# %%
m,c=gradient(x,y)
# Out:
# [1714 1664 1760 1685 1693 1670 1764 1764 1792 1850 1735 1775 1735 1712
#  1773 1872 1755 1674 1842 1786 1761 1722 1663 1687 1974 1826 1787 1821
#  2020 1794 1769 1934 1775 1855 1880 1849 1808 1954 1777 1831 1865 1850
#  1966 1702 1990 1925 1824 1956 1857 1979 1802 1855 1907 1634 1879 1887
#  1730 1953 1781 1891 1964 1808 1893 2041 1893 1832 1850 1934 1861 1931
#  1933 1778 1975 1934 2021 2015 1997 2020 1843 1936 1810 1987 1962 2050]
# 11.163383333333337
# [1714 1664 1760 1685 1693 1670 1764 1764 1792 1850 1735 1775 1735 1712
#  1773 1872 1755 1674 1842 1786 1761 1722 1663 1687 1974 1826 1787 1821
#  2020 1794 1769 1934 1775 1855 1880 1849 1808 1954 1777 1831 1865 1850
#  1966 1702 1990 1925 1824 1956 1857 1979 1802 1855 1907 1634 1879 1887
#  1730 1953 1781 1891 1964 1808 1893 2041 1893 1832 1850 1934 1861 1931
#  1933 1778 1975 1934 2021 2015 1997 2020 1843 1936 1810 1987 1962 2050]
# 1.1597876761200745
# [1714 1664 1760 1685 1693 1670 1764 1764 1792 1850 1735 1775 1735 1712
# ...

# %%
y_pred=m*x+c

# %%
y_pred
# Out:
# array([3.09251569, 3.00230232, 3.175512  , 3.04019194, 3.05462608,
#        3.01312792, 3.18272907, 3.18272907, 3.23324856, 3.33789608,
#        3.13040531, 3.20257601, 3.13040531, 3.08890716, 3.19896748,
#        3.37758996, 3.16649066, 3.02034499, 3.32346194, 3.22242296,
#        3.17731627, 3.10694983, 3.00049805, 3.04380047, 3.56162525,
#        3.29459366, 3.22422722, 3.28557232, 3.64462156, 3.2368571 ,
#        3.19175041, 3.48945455, 3.20257601, 3.34691742, 3.3920241 ,
#        3.33609181, 3.26211684, 3.5255399 , 3.20618455, 3.303615  ,
#        3.36496009, 3.33789608, 3.54719111, 3.07086448, 3.59049353,
#        3.47321614, 3.29098512, 3.52914844, 3.35052595, 3.57064659,
#        3.25129124, 3.34691742, 3.44073933, 2.94817429, 3.39021984,
#        3.40465398, 3.12138397, 3.52373563, 3.21340162, 3.41187105,
#        3.54358258, 3.26211684, 3.41547958, 3.68251118, 3.41547958,
#        3.30541926, 3.33789608, 3.48945455, 3.35774302, 3.48404175,
# ...

# %%
plt.scatter(x,y,c="g")
plt.plot(x,y_pred,color="b")
plt.show()

# %%
a=np.array([2,3,1,7,9])
b=np.array([4,5,7,14,19])

# %%
def gradient(x,y):
    m=0
    c=0
    ittration=1000
    learning_rate=0.0001
    n=len(x)
    for i in range(ittration):
        y_pred=m*x+c
        cost=(1/n)*sum([j**2 for j in (y-y_pred)])
        m_curr=(-2/n)*sum(x*(y-y_pred))
        c_curr=(-2/n)*sum(y-y_pred)
        m=m-(learning_rate*m_curr)
        c=c-(learning_rate*c_curr)
        print(cost)
    return m,c

# %%
b0,b1=gradient(a,b)
# Out:
# 129.4
# 127.93549772575999
# 126.48821239367089
# 125.05794158174606
# 123.64448524790453
# 122.24764570199
# 120.86722757811896
# 119.5030378073539
# 118.15488559069763
# 116.82258237240549
# 115.50594181361083
# 114.20477976626103
# 112.91891424735964
# 111.64816541351166
# 110.39235553576773
# 109.15130897476443
# 107.92485215615659
# 106.71281354633867
# 105.51502362845133
# 104.3313148786705
# 103.16152174277454
# 102.0054806129879
# 100.86302980509586
# 99.73400953582944
# 98.61826190051538
# 97.51563085098935
# 96.4259621737686
# 95.34910346848145
# 94.2849041265502
# 93.23321531012478
# 92.19388993126393
# 91.16678263136141
# 90.15174976081386
# 89.14864935892781
# 88.15734113406297
# 87.17768644400878
# 86.209548276592
# 85.252791230512
# 84.30728149640146
# 83.3728868381099
# 82.44947657420708
# 81.53692155970376
# 80.63509416798784
# 79.74386827297234
# 78.86311923145354
# 77.99272386567657
# 77.13256044610587
# 76.28250867439822
# 75.44244966657605
# 74.61226593639849
# ...

# %%
y_pred1=b0*a+b1
y_pred1
# Out:
# array([ 4.43814601,  6.44763174,  2.42866029, 14.48557464, 18.5045461 ])

# %%
plt.scatter(a,b,c="g")
plt.plot(a,y_pred1,c="b")
plt.show()
